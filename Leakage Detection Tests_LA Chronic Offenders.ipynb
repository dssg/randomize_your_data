# %% [markdown]
# # Leakage Detection Tests
#
# A series of tests for leakage, demonstrated on the Los Angeles Chronic Offenders database
# Requires a credentials.py file defining the following variables: dbname, user, host, password

# %%
import sys
import os
import math
import warnings

import pandas as pd
import numpy as np
import psycopg2
from sqlalchemy import create_engine
from IPython.core.interactiveshell import InteractiveShell

from credentials import dbname, user, host, password

warnings.filterwarnings(action='once')
InteractiveShell.ast_node_interactivity = "all"
# Out:
# /mnt/data/users/jwang/venv3/lib/python3.4/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
def execute_sql(statement, dbname, user, host, password, isolation = False, results = True):
    """
    Use psycopg2 to execute PostgreSQL queries
    
    Input:
        statement (str): SQL statement to run in database
        dbname, user, host, password (str): database credentials
        isolation (bool): indicator for whether to change isolation level to autocommit; True for queries that cannot be run 
            from within a transation (see https://wiki.postgresql.org/wiki/Psycopg2_Tutorial)
        results (bool): indicator for whether the query is expected to output results;
            for example, True for SELECT statements and False for CREATE TABLE statements
    
    Output:
        relation (dataframe): query results or empty dataframe if results = False
    """
    conn = psycopg2.connect("dbname={} user={} host={} password={}".format(dbname, user, host, password))
    cur = conn.cursor()
    if isolation:
        conn.set_isolation_level(psycopg2.extensions.ISOLATION_LEVEL_AUTOCOMMIT)
    cur.execute(statement)
    relation = pd.DataFrame()
    if results:
        results = cur.fetchall()
        colnames = [desc[0] for desc in cur.description]
        relation = pd.DataFrame(results, columns=colnames)
    cur.close()
    conn.close()
    return relation

# %% [markdown]
# ## I. Create a randomized version of the raw schema

# %% [markdown]
# Pull the information schema from selected database.

# %%
# name of the database schema containing raw data to be randomized
RAW_SCHEMA = 'raw'

# %%
statement = "SELECT * FROM information_schema.tables;"
tables = execute_sql(statement, dbname, user, host, password)

# %%
tables
# Out:
#                     table_catalog        table_schema  \
# 0    los_angeles_chronic_offender                ccms
# 1    los_angeles_chronic_offender                ccms
# 2    los_angeles_chronic_offender                ccms
# 3    los_angeles_chronic_offender                ccms
# 4    los_angeles_chronic_offender                ccms
# 5    los_angeles_chronic_offender                ccms
# 6    los_angeles_chronic_offender            kit_test
# 7    los_angeles_chronic_offender        dedupe_cases
# 8    los_angeles_chronic_offender                ccms
# 9    los_angeles_chronic_offender                ccms
# 10   los_angeles_chronic_offender          pg_catalog
# 11   los_angeles_chronic_offender                ccms
# 12   los_angeles_chronic_offender  dedupe_exploration
# 13   los_angeles_chronic_offender     data_dictionary
# 14   los_angeles_chronic_offender          pg_catalog
# 15   los_angeles_chronic_offender              public
# 16   los_angeles_chronic_offender              public
# 17   los_angeles_chronic_offender          pg_catalog
# 18   los_angeles_chronic_offender          pg_catalog
# 19   los_angeles_chronic_offender          pg_catalog
# 20   los_angeles_chronic_offender          pg_catalog
# 21   los_angeles_chronic_offender          pg_catalog
# 22   los_angeles_chronic_offender          pg_catalog
# 23   los_angeles_chronic_offender              public
# 24   los_angeles_chronic_offender          pg_catalog
# 25   los_angeles_chronic_offender          pg_catalog
# 26   los_angeles_chronic_offender          pg_catalog
# 27   los_angeles_chronic_offender          pg_catalog
# 28   los_angeles_chronic_offender          pg_catalog
# 29   los_angeles_chronic_offender          pg_catalog
# ..                            ...                 ...
# 934  los_angeles_chronic_offender              public
# 935  los_angeles_chronic_offender        ccms02202018
# 936  los_angeles_chronic_offender            features
# 937  los_angeles_chronic_offender        ccms02202018
# 938  los_angeles_chronic_offender              public
# 939  los_angeles_chronic_offender            features
# 940  los_angeles_chronic_offender            features
# 941  los_angeles_chronic_offender            features
# 942  los_angeles_chronic_offender            features
# 943  los_angeles_chronic_offender            features
# 944  los_angeles_chronic_offender            features
# 945  los_angeles_chronic_offender        ccms02202018
# 946  los_angeles_chronic_offender            features
# 947  los_angeles_chronic_offender        ccms02202018
# 948  los_angeles_chronic_offender            features
# 949  los_angeles_chronic_offender               lists
# 950  los_angeles_chronic_offender               lists
# 951  los_angeles_chronic_offender               lists
# 952  los_angeles_chronic_offender        ccms02202018
# 953  los_angeles_chronic_offender            features
# 954  los_angeles_chronic_offender          validation
# 955  los_angeles_chronic_offender          validation
# 956  los_angeles_chronic_offender          validation
# 957  los_angeles_chronic_offender          validation
# 958  los_angeles_chronic_offender          validation
# 959  los_angeles_chronic_offender          validation
# 960  los_angeles_chronic_offender          validation
# 961  los_angeles_chronic_offender          validation
# 962  los_angeles_chronic_offender          validation
# 963  los_angeles_chronic_offender          validation
#
#                                             table_name  table_type  \
# 0                                                cases  BASE TABLE
# 1                                              addinfo  BASE TABLE
# 2                                             casesaka  BASE TABLE
# 3                                          casescharge  BASE TABLE
# 4                                            casesflag  BASE TABLE
# 5                                             citation  BASE TABLE
# 6                                             citation  BASE TABLE
# 7                                             entities  BASE TABLE
# 8                                             status_h  BASE TABLE
# 9                                                 prob  BASE TABLE
# 10                                             pg_type  BASE TABLE
# 11                                             probcon  BASE TABLE
# 12                                      coding_results  BASE TABLE
# 13                                          case_flags  BASE TABLE
# 14                                            pg_roles        VIEW
# 15                                   geography_columns        VIEW
# 16                                    geometry_columns        VIEW
# 17                                            pg_group        VIEW
# 18                                             pg_user        VIEW
# 19                                       pg_shseclabel  BASE TABLE
# 20                                        pg_collation  BASE TABLE
# 21                                            pg_range  BASE TABLE
# 22                                        pg_transform  BASE TABLE
# 23                                     spatial_ref_sys  BASE TABLE
# 24                                         pg_policies        VIEW
# 25                                         pg_settings        VIEW
# 26                                            pg_rules        VIEW
# 27                                            pg_views        VIEW
# 28                                           pg_tables        VIEW
# 29                                         pg_matviews        VIEW
# ..                                                 ...         ...
# 934                                               test  BASE TABLE
# 935                                   comp_old02202018  BASE TABLE
# 936  7509961f6f307e55a6744b1af3762c9d_matrix_entity...  BASE TABLE
# 937                               court_status02202018  BASE TABLE
# 938                                             labels  BASE TABLE
# 939                                priors_1y_entity_id  BASE TABLE
# 940                              priors_1y_aggregation  BASE TABLE
# 941                                priors_3y_entity_id  BASE TABLE
# 942                              priors_3y_aggregation  BASE TABLE
# 943                                priors_5y_entity_id  BASE TABLE
# 944                              priors_5y_aggregation  BASE TABLE
# 945                                     docass02202018  BASE TABLE
# 946  5a40a0b25fecd54adf1425578d2b012c_matrix_entity...  BASE TABLE
# 947                                       prob02202018  BASE TABLE
# 948  53c61a201910975c4f3d0deae2038ce1_matrix_entity...  BASE TABLE
# 949                           list_baseline_5yr_012018  BASE TABLE
# 950                           list_baseline_3yr_012018  BASE TABLE
# 951                           list_baseline_1yr_012018  BASE TABLE
# 952                                    probcon02202018  BASE TABLE
# 953  c2b294d41b23bc0f7f31e40cef4c920d_matrix_entity...  BASE TABLE
# 954                        join_cases_bookings_booking  BASE TABLE
# 955                          join_cases_bookings_cases  BASE TABLE
# 956                            join_baseline_5yr_cases  BASE TABLE
# 957                            join_baseline_3yr_cases  BASE TABLE
# 958                                           newcases  BASE TABLE
# 959                            join_baseline_1yr_cases  BASE TABLE
# 960                          join_baseline_5yr_booking  BASE TABLE
# 961                          join_baseline_3yr_booking  BASE TABLE
# 962                                         newbooking  BASE TABLE
# 963                          join_baseline_1yr_booking  BASE TABLE
#
#     self_referencing_column_name reference_generation  \
# 0                           None                 None
# 1                           None                 None
# 2                           None                 None
# 3                           None                 None
# 4                           None                 None
# 5                           None                 None
# 6                           None                 None
# 7                           None                 None
# 8                           None                 None
# 9                           None                 None
# 10                          None                 None
# 11                          None                 None
# 12                          None                 None
# 13                          None                 None
# 14                          None                 None
# 15                          None                 None
# 16                          None                 None
# 17                          None                 None
# 18                          None                 None
# 19                          None                 None
# 20                          None                 None
# 21                          None                 None
# 22                          None                 None
# 23                          None                 None
# 24                          None                 None
# 25                          None                 None
# 26                          None                 None
# 27                          None                 None
# 28                          None                 None
# 29                          None                 None
# ..                           ...                  ...
# 934                         None                 None
# 935                         None                 None
# 936                         None                 None
# 937                         None                 None
# 938                         None                 None
# 939                         None                 None
# 940                         None                 None
# 941                         None                 None
# 942                         None                 None
# 943                         None                 None
# 944                         None                 None
# 945                         None                 None
# 946                         None                 None
# 947                         None                 None
# 948                         None                 None
# 949                         None                 None
# 950                         None                 None
# 951                         None                 None
# 952                         None                 None
# 953                         None                 None
# 954                         None                 None
# 955                         None                 None
# 956                         None                 None
# 957                         None                 None
# 958                         None                 None
# 959                         None                 None
# 960                         None                 None
# 961                         None                 None
# 962                         None                 None
# 963                         None                 None
#
#     user_defined_type_catalog user_defined_type_schema user_defined_type_name  \
# 0                        None                     None                   None
# 1                        None                     None                   None
# 2                        None                     None                   None
# 3                        None                     None                   None
# 4                        None                     None                   None
# 5                        None                     None                   None
# 6                        None                     None                   None
# 7                        None                     None                   None
# 8                        None                     None                   None
# 9                        None                     None                   None
# 10                       None                     None                   None
# 11                       None                     None                   None
# 12                       None                     None                   None
# 13                       None                     None                   None
# 14                       None                     None                   None
# 15                       None                     None                   None
# 16                       None                     None                   None
# 17                       None                     None                   None
# 18                       None                     None                   None
# 19                       None                     None                   None
# 20                       None                     None                   None
# 21                       None                     None                   None
# 22                       None                     None                   None
# 23                       None                     None                   None
# 24                       None                     None                   None
# 25                       None                     None                   None
# 26                       None                     None                   None
# 27                       None                     None                   None
# 28                       None                     None                   None
# 29                       None                     None                   None
# ..                        ...                      ...                    ...
# 934                      None                     None                   None
# 935                      None                     None                   None
# 936                      None                     None                   None
# 937                      None                     None                   None
# 938                      None                     None                   None
# 939                      None                     None                   None
# 940                      None                     None                   None
# 941                      None                     None                   None
# 942                      None                     None                   None
# 943                      None                     None                   None
# 944                      None                     None                   None
# 945                      None                     None                   None
# 946                      None                     None                   None
# 947                      None                     None                   None
# 948                      None                     None                   None
# 949                      None                     None                   None
# 950                      None                     None                   None
# 951                      None                     None                   None
# 952                      None                     None                   None
# 953                      None                     None                   None
# 954                      None                     None                   None
# 955                      None                     None                   None
# 956                      None                     None                   None
# 957                      None                     None                   None
# 958                      None                     None                   None
# 959                      None                     None                   None
# 960                      None                     None                   None
# 961                      None                     None                   None
# 962                      None                     None                   None
# 963                      None                     None                   None
#
#     is_insertable_into is_typed commit_action
# 0                  YES       NO          None
# 1                  YES       NO          None
# 2                  YES       NO          None
# 3                  YES       NO          None
# 4                  YES       NO          None
# 5                  YES       NO          None
# 6                  YES       NO          None
# 7                  YES       NO          None
# 8                  YES       NO          None
# 9                  YES       NO          None
# 10                 YES       NO          None
# 11                 YES       NO          None
# 12                 YES       NO          None
# 13                 YES       NO          None
# 14                  NO       NO          None
# 15                  NO       NO          None
# 16                 YES       NO          None
# 17                 YES       NO          None
# 18                  NO       NO          None
# 19                 YES       NO          None
# 20                 YES       NO          None
# 21                 YES       NO          None
# 22                 YES       NO          None
# 23                 YES       NO          None
# 24                  NO       NO          None
# 25                  NO       NO          None
# 26                  NO       NO          None
# 27                  NO       NO          None
# 28                  NO       NO          None
# 29                  NO       NO          None
# ..                 ...      ...           ...
# 934                YES       NO          None
# 935                YES       NO          None
# 936                YES       NO          None
# 937                YES       NO          None
# 938                YES       NO          None
# 939                YES       NO          None
# 940                YES       NO          None
# 941                YES       NO          None
# 942                YES       NO          None
# 943                YES       NO          None
# 944                YES       NO          None
# 945                YES       NO          None
# 946                YES       NO          None
# 947                YES       NO          None
# 948                YES       NO          None
# 949                YES       NO          None
# 950                YES       NO          None
# 951                YES       NO          None
# 952                YES       NO          None
# 953                YES       NO          None
# 954                YES       NO          None
# 955                YES       NO          None
# 956                YES       NO          None
# 957                YES       NO          None
# 958                YES       NO          None
# 959                YES       NO          None
# 960                YES       NO          None
# 961                YES       NO          None
# 962                YES       NO          None
# 963                YES       NO          None
#
# [964 rows x 12 columns]

# %% [markdown]
# Select the schema containing raw datasets to be randomized. For this tutorial, the schema is named ???

# %%
raw = tables[tables.table_schema == RAW_SCHEMA]
raw.head()
# Out:
# Empty DataFrame
# Columns: [table_catalog, table_schema, table_name, table_type, self_referencing_column_name, reference_generation, user_defined_type_catalog, user_defined_type_schema, user_defined_type_name, is_insertable_into, is_typed, commit_action]
# Index: []

# %% [markdown]
# First created the _randomized schema if it doesn't yet exist

# %%
statement = "CREATE SCHEMA IF NOT EXISTS {}_randomized;".format(RAW_SCHEMA)
output = execute_sql(statement, dbname, user, host, password, port, isolation=True, results = False)

# %% [markdown]
# Randomize every table in raw and write output to _randomized schema

# %%
for table_name in raw.table_name:
    print("Working on table {}".format(table_name))
    
    # Pull the table from original schema
    print("\tPulling table")
    statement = "SELECT * FROM {}.{};".format(RAW_SCHEMA, table_name)
    table = execute_sql(statement, dbname, user, host, password, port)
    
    # Randomize the table
    print("\tRandomizing")
    randomized_table = randomize(table)
    
    # Make a new table in _randomized schema
    print("\tUploading randomized version")
    statement = "CREATE TABLE IF NOT EXISTS {}_randomized.{} (LIKE {}.{});".format(RAW_SCHEMA, table_name, RAW_SCHEMA, table_name)
    output = execute_sql(statement, dbname, user, host, password, port, isolation = True, results = False)
    
    # Write results into new table
    statement = "SELECT COUNT(*) FROM {}_randomized.{};".format(RAW_SCHEMA, table_name)
    output = execute_sql(statement, dbname, user, host, password, port)
    if output.iloc[0,0]>0: #  do nothing if new table already contains data
        print("\t*****SKIPPING TABLE {} -- it already has data".format(table_name))
    else:
        engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(user, password, host, port, dbname))
        randomized_table.to_sql(table_name, engine, schema = '{}_randomized'.format(RAW_SCHEMA), index = False, if_exists='append')

# %% [markdown]
# ## II. Edit + execute preprocessing and config files so that they point to the newly randomized raw schema
#
# New versions of the preprocessing and config files with an "_edited" suffix will be produced.

# %% [markdown]
# ## III. Run an experiment with this new setup

# %% [markdown]
# Now that we've set up randomized versions of the original schemas in the database and created a new config file for a randomized experiment, it's time to run the actual triage experiment.
#
# **NOTE**: This must be done from the command line!
#
# - First validate the new config file. For this tutorial: ./tutorial.sh triage --config_file inspections_test_edited.yaml validate
# - Then execute the experiment. For this tutorial: ./tutorial.sh triage --config_file inspections_test_edited.yaml run

# %% [markdown]
# ## IV. Align the results of randomized experiment against original experiment
#
# First, we need to map the model groups from our new, randomized experiment to the model groups from the original experiment

# %% [markdown]
# Confirm that we now see a set of model groups where purpose = "leakage-detection"

# %%
statement = "SELECT * FROM results.model_groups;"
model_groups = execute_sql(statement, dbname, user, host, password, port)
model_groups
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-afa8ea99b77b> in <module>()
#       1 statement = "SELECT * FROM results.model_groups;"
# ----> 2 model_groups = execute_sql(statement, dbname, user, host, password, port)
#       3 model_groups
#
# NameError: name 'port' is not defined

# %% [markdown]
# Recall that a model group is defined by the classifier (model_type), its parameters (model_parameters), the features (feature_list), and the model_config. Since we varied the "purpose" key within model_config for these randomized experiments, all other properties of a model group should be used as index keys. This includes other model group keys in the model_config column.

# %%
# pull out all model group keys from model_config column and make new columns from them
list_of_lists = list(model_groups.model_config.apply(lambda x: list(x.keys())))
keys = set([key for x in list_of_lists for key in x])

for key in keys:
    model_groups[key] = model_groups.model_config.apply(lambda x: x.get(key, None))

# %%
# convert model_parameters and feature_list columns to strings so they can be used as index keys
model_groups['model_parameters'] = model_groups.model_parameters.apply(lambda x: ', '.join('{}{}'.format(key, val) for key, val in x.items()))
model_groups['feature_list'] = model_groups.feature_list.apply(lambda x: ', '.join(x))

# %%
index_cols = [col for col in model_groups.columns if col not in ['purpose', 'model_group_id', 'model_config']]
index_cols

# %%
model_groups = model_groups.set_index(index_cols)

# %% [markdown]
# Join the original and randomized model groups to create a wide (rather than long) version of model_group table. Each row of model_groups_wide corresponds to a particular model group configuration and indicates the model group ids of the original vs randomized versions.

# %%
# define original "purpose" model group key
ORIG_PURPOSE = 'test'

# %%
orig = model_groups[model_groups.purpose == ORIG_PURPOSE]
rand = model_groups[model_groups.purpose == 'leakage-detection']
model_groups_wide = pd.merge(orig[['model_group_id']], rand[['model_group_id']], how='right', left_index=True, right_index=True, suffixes = ['_orig', '_rand'])

# %%
model_groups_wide

# %% [markdown]
# Pick a model group configuration on which to test for leakage. Let's go with the first row, where model_group_id_orig = 1, model_group_id_rand = 7

# %%
# create variables for the model_group id's you selected
GROUP_ID_ORIG = 1
GROUP_ID_RAND = 7

# %% [markdown]
# Look at the models relevant to each model group

# %%
statement = "SELECT * FROM results.models where model_group_id = {};".format(GROUP_ID_ORIG)
models_orig = execute_sql(statement, dbname, user, host, password, port)
models_orig

# %%
statement = "SELECT * FROM results.models where model_group_id = {};".format(GROUP_ID_RAND)
models_rand = execute_sql(statement, dbname, user, host, password, port)
models_rand

# %% [markdown]
# Pick a pair of comparable models on which to test for leakage, i.e. with matching train_end_time. Let's go with the first row of each table, i.e. model_id numbers 1 (original) and 13 (random).
# Grab the predictions made by each of these models.

# %%
# create variables for the model id's you selected
MODEL_ID_ORIG = 1
MODEL_ID_RAND = 13

# %%
statement = "SELECT * FROM results.predictions where model_id = {};".format(MODEL_ID_ORIG)
predictions_orig = execute_sql(statement, dbname, user, host, password, port)
predictions_orig

# %%
predictions_orig_sorted = predictions_orig.sort_values(by=['score', 'label_value'], ascending=[False, True])

# %%
statement = "SELECT * FROM results.predictions where model_id = {};".format(MODEL_ID_RAND)
predictions_rand = execute_sql(statement, dbname, user, host, password, port)
predictions_rand

# %%
predictions_rand_sorted = predictions_rand.sort_values(by=['score', 'label_value'], ascending=[False, True])

# %% [markdown]
# Grab the evaluation metrics for each of these models.

# %%
statement = "SELECT * FROM results.evaluations where model_id = {};".format(MODEL_ID_ORIG)
evaluations_orig = execute_sql(statement, dbname, user, host, password, port)
evaluations_orig

# %%
statement = "SELECT * FROM results.evaluations where model_id = {};".format(MODEL_ID_RAND)
evaluations_rand = execute_sql(statement, dbname, user, host, password, port)
evaluations_rand

# %% [markdown]
# ## V. Review the predictions and important features of randomized model
