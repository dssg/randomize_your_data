# %% [markdown]
# # Purpose
# Series of steps to test for leakage in an existing project.
#
# The example below is applied to the [Dirty Duck Inspections Tutorial](https://github.com/dssg/dirtyduck), using City of Chicago inspections prioritization data. We assume that you have already followed the steps in the tutorial up to and including the Inspections section. The variables in ALL CAPS are things that need to be customized for each project, so make a copy of this notebook and personalize it for your project.
#
# # Process

# %%
import sys
import os
import math
import warnings

import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import psycopg2
from sqlalchemy import create_engine

from sklearn import linear_model
from sklearn import metrics 
from sklearn.model_selection import TimeSeriesSplit, train_test_split
from IPython.core.interactiveshell import InteractiveShell

from dd_credentials import * # credentials file containing database login variables (dbname, user, host, password, port)

warnings.filterwarnings(action='once')
InteractiveShell.ast_node_interactivity = "all"

# %%
def execute_sql(statement, dbname, user, host, password, port, isolation = False, results = True):
    """
    Use psycopg2 to execute PostgreSQL queries
    
    Input:
        statement (str): SQL statement to run in database
        dbname, user, host, password (str): database credentials
        isolation (bool): indicator for whether to change isolation level to autocommit; True for queries that cannot be run 
            from within a transation (see https://wiki.postgresql.org/wiki/Psycopg2_Tutorial), e.g. queries other than SELECT
        results (bool): indicator for whether the query is expected to output results;
            for example, True for SELECT statements and False for CREATE TABLE statements
    
    Output:
        relation (dataframe): query results or empty dataframe if results = False
    """
    conn = psycopg2.connect("dbname={} user={} host={} password={} port={}".format(dbname, user, host, password, port))
    cur = conn.cursor()
    if isolation:
        conn.set_isolation_level(psycopg2.extensions.ISOLATION_LEVEL_AUTOCOMMIT)
    cur.execute(statement)
    relation = pd.DataFrame()
    if results:
        results = cur.fetchall()
        colnames = [desc[0] for desc in cur.description]
        relation = pd.DataFrame(results, columns=colnames)
    cur.close()
    conn.close()
    return relation

# %%
def randomize(df, do_not_randomize = None):
    """
    Randomize column values of a file. Each column is randomized independently.
    
    Inputs:
        df (dataframe): dataframe to randomize
        do_not_randomize (list): optional list of strings indicating names of 
            columns that should not be randomized
    Outputs:
        df (dataframe): dataframe of randomized data
    """     
    df_random = df.copy()
    if do_not_randomize:
        cols = [c for c in df.columns if c not in do_not_randomize]
    else:
        cols = df.columns
        
    for col in cols:
        #print('\t\tRandomizing column ' + col)
        df_random[col] = np.random.permutation(df_random[col])

    return df_random

# %%
# source: https://overlaid.net/2016/02/08/replace-words-in-files-or-strings-using-python/
def do_replacement(base_text, word_map):
    """
    Helper function for replace_words_in_file. Make replacements in base_text, as 
    indicated in  word_map.
    """
    for key, val in word_map.items():
        base_text = base_text.replace(key, val)
    return base_text

def replace_words_in_file(read_from, write_to, word_map):
    """
    Create copy of a file with certain words replaced
    
    Inputs
        read_from: name of file to read from
        write_to: name of new file to be created
        word_map: dictionary of mappings between words and their replacements
            (e.g. {'old_word': 'new_word'})
    Outputs
        None. Will create a new file with the name given in write_to
        
    """
    # Open your desired file as 't' and read the lines into string 'tempstr'
    t = open(read_from, 'r')
    tempstr = t.read()
    t.close()

    # Using the "replace_words" function, we'll pass in our tempstr to be used as the base, 
    # and our device_values to be used as replacement.  
    output = do_replacement(tempstr, word_map)

    # Write out the new config file
    fout = open(write_to, 'w')
    fout.write(output)
    fout.close()

# %%
def get_new_filename(filename, suffix):
    """
    Output a new filename (str) given a filename and suffix to append. Assumes file extension at the end is separated by a period.
    """
    k = filename.rfind(".")
    new_filename = filename[:k] + suffix + '.' + filename[k+1:]
    return new_filename

# %%
def generate_binary_pred(y_scores, k):
    """
    Generate binary predictions, where top k proportion of highest y_scores receive class of 1
    """
    cutoff = int(len(y_scores) * k)
    ind = np.argpartition(y_scores, -cutoff)[-cutoff:] # indices of top k probabilities
    y_pred = np.zeros(y_scores.shape[0])
    y_pred[ind] = 1
    return y_pred

# %% [markdown]
# ## I. Create a randomized version of the raw schema

# %% [markdown]
# Pull the information schema from selected database.

# %%
# name of the database schema containing raw data to be randomized
RAW_SCHEMA = 'raw'

# %%
statement = "SELECT * FROM information_schema.tables;"
tables = execute_sql(statement, dbname, user, host, password, port)

# %%
tables
# Out:
#     table_catalog        table_schema                    table_name  \
# 0            food         inspections             active_facilities
# 1            food             postgis             geography_columns
# 2            food             postgis              geometry_columns
# 3            food             postgis               spatial_ref_sys
# 4            food             postgis                raster_columns
# 5            food             postgis              raster_overviews
# 6            food             cleaned                   inspections
# 7            food         inspections                        failed
# 8            food         inspections        failed_major_violation
# 9            food          pg_catalog                  pg_statistic
# 10           food          pg_catalog                       pg_type
# 11           food             cleaned                    violations
# 12           food          pg_catalog                     pg_policy
# 13           food          pg_catalog                     pg_authid
# 14           food          pg_catalog                     pg_shadow
# 15           food                 raw                   inspections
# 16           food            semantic                      entities
# 17           food            semantic                        events
# 18           food          pg_catalog                   pg_settings
# 19           food          pg_catalog             pg_hba_file_rules
# 20           food          pg_catalog              pg_file_settings
# 21           food          pg_catalog                     pg_config
# 22           food          pg_catalog               pg_user_mapping
# 23           food          pg_catalog  pg_replication_origin_status
# 24           food          pg_catalog               pg_subscription
# 25           food          pg_catalog           pg_stat_user_tables
# 26           food          pg_catalog      pg_stat_xact_user_tables
# 27           food          pg_catalog                  pg_attribute
# 28           food          pg_catalog                       pg_proc
# 29           food          pg_catalog                      pg_class
# ..            ...                 ...                           ...
# 171          food  information_schema              table_privileges
# 172          food  information_schema         foreign_table_options
# 173          food  information_schema             role_table_grants
# 174          food  information_schema              view_table_usage
# 175          food  information_schema                        tables
# 176          food  information_schema                    transforms
# 177          food  information_schema      triggered_update_columns
# 178          food  information_schema         foreign_data_wrappers
# 179          food  information_schema                      triggers
# 180          food  information_schema                         views
# 181          food  information_schema                udt_privileges
# 182          food  information_schema               role_udt_grants
# 183          food  information_schema              usage_privileges
# 184          food  information_schema          data_type_privileges
# 185          food  information_schema             role_usage_grants
# 186          food  information_schema            user_defined_types
# 187          food  information_schema           _pg_foreign_servers
# 188          food  information_schema             view_column_usage
# 189          food  information_schema                 element_types
# 190          food  information_schema     _pg_foreign_table_columns
# 191          food  information_schema                column_options
# 192          food  information_schema     _pg_foreign_data_wrappers
# 193          food  information_schema        foreign_server_options
# 194          food  information_schema  foreign_data_wrapper_options
# 195          food  information_schema          user_mapping_options
# 196          food  information_schema               foreign_servers
# 197          food  information_schema            _pg_foreign_tables
# 198          food  information_schema                foreign_tables
# 199          food  information_schema             _pg_user_mappings
# 200          food  information_schema                 user_mappings
#
#      table_type self_referencing_column_name reference_generation  \
# 0    BASE TABLE                         None                 None
# 1          VIEW                         None                 None
# 2          VIEW                         None                 None
# 3    BASE TABLE                         None                 None
# 4          VIEW                         None                 None
# 5          VIEW                         None                 None
# 6    BASE TABLE                         None                 None
# 7    BASE TABLE                         None                 None
# 8    BASE TABLE                         None                 None
# 9    BASE TABLE                         None                 None
# 10   BASE TABLE                         None                 None
# 11   BASE TABLE                         None                 None
# 12   BASE TABLE                         None                 None
# 13   BASE TABLE                         None                 None
# 14         VIEW                         None                 None
# 15   BASE TABLE                         None                 None
# 16   BASE TABLE                         None                 None
# 17   BASE TABLE                         None                 None
# 18         VIEW                         None                 None
# 19         VIEW                         None                 None
# 20         VIEW                         None                 None
# 21         VIEW                         None                 None
# 22   BASE TABLE                         None                 None
# 23         VIEW                         None                 None
# 24   BASE TABLE                         None                 None
# 25         VIEW                         None                 None
# 26         VIEW                         None                 None
# 27   BASE TABLE                         None                 None
# 28   BASE TABLE                         None                 None
# 29   BASE TABLE                         None                 None
# ..          ...                          ...                  ...
# 171        VIEW                         None                 None
# 172        VIEW                         None                 None
# 173        VIEW                         None                 None
# 174        VIEW                         None                 None
# 175        VIEW                         None                 None
# 176        VIEW                         None                 None
# 177        VIEW                         None                 None
# 178        VIEW                         None                 None
# 179        VIEW                         None                 None
# 180        VIEW                         None                 None
# 181        VIEW                         None                 None
# 182        VIEW                         None                 None
# 183        VIEW                         None                 None
# 184        VIEW                         None                 None
# 185        VIEW                         None                 None
# 186        VIEW                         None                 None
# 187        VIEW                         None                 None
# 188        VIEW                         None                 None
# 189        VIEW                         None                 None
# 190        VIEW                         None                 None
# 191        VIEW                         None                 None
# 192        VIEW                         None                 None
# 193        VIEW                         None                 None
# 194        VIEW                         None                 None
# 195        VIEW                         None                 None
# 196        VIEW                         None                 None
# 197        VIEW                         None                 None
# 198        VIEW                         None                 None
# 199        VIEW                         None                 None
# 200        VIEW                         None                 None
#
#     user_defined_type_catalog user_defined_type_schema user_defined_type_name  \
# 0                        None                     None                   None
# 1                        None                     None                   None
# 2                        None                     None                   None
# 3                        None                     None                   None
# 4                        None                     None                   None
# 5                        None                     None                   None
# 6                        None                     None                   None
# 7                        None                     None                   None
# 8                        None                     None                   None
# 9                        None                     None                   None
# 10                       None                     None                   None
# 11                       None                     None                   None
# 12                       None                     None                   None
# 13                       None                     None                   None
# 14                       None                     None                   None
# 15                       None                     None                   None
# 16                       None                     None                   None
# 17                       None                     None                   None
# 18                       None                     None                   None
# 19                       None                     None                   None
# 20                       None                     None                   None
# 21                       None                     None                   None
# 22                       None                     None                   None
# 23                       None                     None                   None
# 24                       None                     None                   None
# 25                       None                     None                   None
# 26                       None                     None                   None
# 27                       None                     None                   None
# 28                       None                     None                   None
# 29                       None                     None                   None
# ..                        ...                      ...                    ...
# 171                      None                     None                   None
# 172                      None                     None                   None
# 173                      None                     None                   None
# 174                      None                     None                   None
# 175                      None                     None                   None
# 176                      None                     None                   None
# 177                      None                     None                   None
# 178                      None                     None                   None
# 179                      None                     None                   None
# 180                      None                     None                   None
# 181                      None                     None                   None
# 182                      None                     None                   None
# 183                      None                     None                   None
# 184                      None                     None                   None
# 185                      None                     None                   None
# 186                      None                     None                   None
# 187                      None                     None                   None
# 188                      None                     None                   None
# 189                      None                     None                   None
# 190                      None                     None                   None
# 191                      None                     None                   None
# 192                      None                     None                   None
# 193                      None                     None                   None
# 194                      None                     None                   None
# 195                      None                     None                   None
# 196                      None                     None                   None
# 197                      None                     None                   None
# 198                      None                     None                   None
# 199                      None                     None                   None
# 200                      None                     None                   None
#
#     is_insertable_into is_typed commit_action
# 0                  YES       NO          None
# 1                   NO       NO          None
# 2                  YES       NO          None
# 3                  YES       NO          None
# 4                   NO       NO          None
# 5                   NO       NO          None
# 6                  YES       NO          None
# 7                  YES       NO          None
# 8                  YES       NO          None
# 9                  YES       NO          None
# 10                 YES       NO          None
# 11                 YES       NO          None
# 12                 YES       NO          None
# 13                 YES       NO          None
# 14                  NO       NO          None
# 15                 YES       NO          None
# 16                 YES       NO          None
# 17                 YES       NO          None
# 18                  NO       NO          None
# 19                  NO       NO          None
# 20                  NO       NO          None
# 21                  NO       NO          None
# 22                 YES       NO          None
# 23                  NO       NO          None
# 24                 YES       NO          None
# 25                  NO       NO          None
# 26                  NO       NO          None
# 27                 YES       NO          None
# 28                 YES       NO          None
# 29                 YES       NO          None
# ..                 ...      ...           ...
# 171                 NO       NO          None
# 172                 NO       NO          None
# 173                 NO       NO          None
# 174                 NO       NO          None
# 175                 NO       NO          None
# 176                 NO       NO          None
# 177                 NO       NO          None
# 178                 NO       NO          None
# 179                 NO       NO          None
# 180                 NO       NO          None
# 181                 NO       NO          None
# 182                 NO       NO          None
# 183                 NO       NO          None
# 184                 NO       NO          None
# 185                 NO       NO          None
# 186                 NO       NO          None
# 187                 NO       NO          None
# 188                 NO       NO          None
# 189                 NO       NO          None
# 190                 NO       NO          None
# 191                 NO       NO          None
# 192                 NO       NO          None
# 193                 NO       NO          None
# 194                 NO       NO          None
# 195                 NO       NO          None
# 196                 NO       NO          None
# 197                 NO       NO          None
# 198                 NO       NO          None
# 199                 NO       NO          None
# 200                 NO       NO          None
#
# [201 rows x 12 columns]

# %% [markdown]
# Select tables from the raw schema; they will be randomized. In this tutorial, there is only one (raw.inspections).

# %%
raw = tables[tables.table_schema == RAW_SCHEMA]
raw.head()
# Out:
#    table_catalog table_schema   table_name  table_type  \
# 15          food          raw  inspections  BASE TABLE
#
#    self_referencing_column_name reference_generation  \
# 15                         None                 None
#
#    user_defined_type_catalog user_defined_type_schema user_defined_type_name  \
# 15                      None                     None                   None
#
#    is_insertable_into is_typed commit_action
# 15                YES       NO          None

# %% [markdown]
# First created the _randomized schema if it doesn't yet exist

# %%
statement = "CREATE SCHEMA IF NOT EXISTS {}_randomized;".format(RAW_SCHEMA)
output = execute_sql(statement, dbname, user, host, password, port, isolation=True, results = False)

# %% [markdown]
# Randomize every table in raw and write output to _randomized schema

# %%
for table_name in raw.table_name:
    print("Working on table {}".format(table_name))
    
    # Pull the table from original schema
    print("\tPulling table")
    statement = "SELECT * FROM {}.{};".format(RAW_SCHEMA, table_name)
    table = execute_sql(statement, dbname, user, host, password, port)
    
    # Randomize the table
    print("\tRandomizing")
    randomized_table = randomize(table)
    
    # Make a new table in _randomized schema
    print("\tUploading randomized version")
    statement = "CREATE TABLE IF NOT EXISTS {}_randomized.{} (LIKE {}.{});".format(RAW_SCHEMA, table_name, RAW_SCHEMA, table_name)
    output = execute_sql(statement, dbname, user, host, password, port, isolation = True, results = False)
    
    # Write results into new table
    statement = "SELECT COUNT(*) FROM {}_randomized.{};".format(RAW_SCHEMA, table_name)
    output = execute_sql(statement, dbname, user, host, password, port)
    if output.iloc[0,0]>0: #  do nothing if new table already contains data
        print("\t*****SKIPPING TABLE {} -- it already has data".format(table_name))
    else:
        engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(user, password, host, port, dbname))
        randomized_table.to_sql(table_name, engine, schema = '{}_randomized'.format(RAW_SCHEMA), index = False, if_exists='append')
# Out:
# Working on table inspections
# 	Pulling table
# 	Randomizing
# 	Uploading randomized version

# %% [markdown]
# ## II. Edit + execute preprocessing and config files so that they point to the newly randomized raw schema
#
# New versions of the preprocessing and config files with an "_edited" suffix will be produced.

# %% [markdown]
# Make list of preprocessing files that get RAW_SCHEMA ready for triage experiments. The list should be in correct execution order, and file names should have some extension (e.g. .sql).
#
# NOTE: The code below currently only works for .sql files. Need to add .py flexibility if necessary.

# %%
PREPROC_FILES = ['/home/ubuntu/dirtyduck/sql/create_cleaned_inspections_table.sql',
                 '/home/ubuntu/dirtyduck/sql/create_violations_table.sql',
                 '/home/ubuntu/dirtyduck/sql/create_semantic_tables.sql',
                 '/home/ubuntu/dirtyduck/sql/create_inspections_schema.sql'
                ]

# %% [markdown]
# Also define the experiment config file name

# %%
EXP_CONFIG = "/home/ubuntu/dirtyduck/triage/experiment_config/inspections_test.yaml"

# %% [markdown]
# Make a dictionary of text replacements to apply across every preprocessing & config file. This should include:
# - Names of schemas that are produced during preprocessing. Add a _randomized suffix to each of them.
# - The "purpose" model group key from the experiment config file. In order to avoid overwriting existing model groups, the purpose must be changed to indicate that this experiment is for leakage detection.

# %%
WORD_MAP = {RAW_SCHEMA+'.': RAW_SCHEMA+'_randomized.', 
    'cleaned.': 'cleaned_randomized.', 
    'semantic.': 'semantic_randomized.',
    'inspections.': 'inspections_randomized.',
    "purpose: 'test'": "purpose: 'leakage-detection'"}

# %% [markdown]
# Apply find+replace to every preprocessing file.
#
# **NOTE**: Be sure to open the outputted files (with "_edited" suffix) to check that no unexpected replacements were made and that all necessary replacements are made. In this case, we have to manually edit some schema creation statements.

# %%
preproc_files_edited = []
for filename in PREPROC_FILES:
    new_filename = get_new_filename(filename, "_edited")
    replace_words_in_file(filename, new_filename, WORD_MAP)
    preproc_files_edited.append(new_filename)

# %% [markdown]
# Execute the edited preprocessing files

# %%
preproc_files_edited
# Out:
# ['/home/ubuntu/dirtyduck/sql/create_cleaned_inspections_table_edited.sql',
#  '/home/ubuntu/dirtyduck/sql/create_violations_table_edited.sql',
#  '/home/ubuntu/dirtyduck/sql/create_semantic_tables_edited.sql',
#  '/home/ubuntu/dirtyduck/sql/create_inspections_schema_edited.sql']

# %%
for filename in preproc_files_edited:
    print("Executing file ", filename)
    conn = psycopg2.connect("dbname={} user={} host={} password={} port={}".format(dbname, user, host, password, port))
    conn.set_isolation_level(psycopg2.extensions.ISOLATION_LEVEL_AUTOCOMMIT)
    with conn.cursor() as cursor:
        with open(filename, 'r') as f:
            cursor.execute(f.read())
# Out:
# Executing file  /home/ubuntu/dirtyduck/sql/create_cleaned_inspections_table_edited.sql
# Executing file  /home/ubuntu/dirtyduck/sql/create_violations_table_edited.sql
# Executing file  /home/ubuntu/dirtyduck/sql/create_semantic_tables_edited.sql
# Executing file  /home/ubuntu/dirtyduck/sql/create_inspections_schema_edited.sql

# %% [markdown]
# Now edit the experiment config file in a similar fashion. Apply find+replace to config file.
#
# **NOTE**: Again, be sure to open the outputted file (with "_edited" suffix) to check that no unexpected replacements were made and that all necessary replacements are made.
# In this case, we increased test_durations and test_label_timespans from 1month to 3month to obtain a wider test window for more variation in predicted results. The same change was made to the original, non-randomized experiment as well.

# %%
new_exp_config = get_new_filename(EXP_CONFIG, '_edited')
replace_words_in_file(EXP_CONFIG, new_exp_config, WORD_MAP)

# %% [markdown]
# ## III. Run an experiment with this new setup

# %% [markdown]
# Now that we've set up randomized versions of the original schemas in the database and created a new config file for a randomized experiment, it's time to run the actual triage experiment.
#
# **NOTE**: This must be done from the command line!
#
# - First validate the new config file. For this tutorial: ./tutorial.sh triage --config_file inspections_test_edited.yaml validate
# - Then execute the experiment. For this tutorial: ./tutorial.sh triage --config_file inspections_test_edited.yaml run

# %%
# Tried running these commands within Jupyter but didn't work
#!!~/dirtyduck/tutorial.sh triage --config_file inspections_test_edited.yaml validate
# Out:
# ['cat: .project-name: No such file or directory']

# %%
#!!~/dirtyduck/tutorial.sh triage --config_file inspections_test_edited.yaml run
# Out:
# ['cat: .project-name: No such file or directory']

# %% [markdown]
# ## IV. Align the results of randomized experiment against original experiment
#
# First, we need to map the model groups from our new, randomized experiment to the model groups from the original experiment

# %% [markdown]
# Confirm that we now see a set of model groups where purpose = "leakage-detection"

# %%
statement = "SELECT * FROM results.model_groups;"
model_groups = execute_sql(statement, dbname, user, host, password, port)
model_groups
# Out:
#     model_group_id                           model_type  \
# 0                1  sklearn.tree.DecisionTreeClassifier
# 1                2  sklearn.tree.DecisionTreeClassifier
# 2                3  sklearn.tree.DecisionTreeClassifier
# 3                4  sklearn.tree.DecisionTreeClassifier
# 4                5  sklearn.tree.DecisionTreeClassifier
# 5                6  sklearn.tree.DecisionTreeClassifier
# 6                7  sklearn.tree.DecisionTreeClassifier
# 7                8  sklearn.tree.DecisionTreeClassifier
# 8                9  sklearn.tree.DecisionTreeClassifier
# 9               10  sklearn.tree.DecisionTreeClassifier
# 10              11  sklearn.tree.DecisionTreeClassifier
# 11              12  sklearn.tree.DecisionTreeClassifier
#
#                                model_parameters  \
# 0           {'max_depth': 1, 'max_features': 1}
# 1      {'max_depth': 1, 'max_features': 'sqrt'}
# 2        {'max_depth': 1, 'max_features': None}
# 3        {'max_depth': None, 'max_features': 1}
# 4   {'max_depth': None, 'max_features': 'sqrt'}
# 5     {'max_depth': None, 'max_features': None}
# 6           {'max_depth': 1, 'max_features': 1}
# 7      {'max_depth': 1, 'max_features': 'sqrt'}
# 8        {'max_depth': 1, 'max_features': None}
# 9        {'max_depth': None, 'max_features': 1}
# 10  {'max_depth': None, 'max_features': 'sqrt'}
# 11    {'max_depth': None, 'max_features': None}
#
#                                          feature_list  \
# 0   [inspections_entity_id_3month_type_canvass_sum...
# 1   [inspections_entity_id_3month_type_canvass_sum...
# 2   [inspections_entity_id_3month_type_canvass_sum...
# 3   [inspections_entity_id_3month_type_canvass_sum...
# 4   [inspections_entity_id_3month_type_canvass_sum...
# 5   [inspections_entity_id_3month_type_canvass_sum...
# 6   [inspections_entity_id_3month_type_canvass_sum...
# 7   [inspections_entity_id_3month_type_canvass_sum...
# 8   [inspections_entity_id_3month_type_canvass_sum...
# 9   [inspections_entity_id_3month_type_canvass_sum...
# 10  [inspections_entity_id_3month_type_canvass_sum...
# 11  [inspections_entity_id_3month_type_canvass_sum...
#
#                                          model_config
# 0   {'purpose': 'leakage-detection', 'experiment_t...
# 1   {'purpose': 'leakage-detection', 'experiment_t...
# 2   {'purpose': 'leakage-detection', 'experiment_t...
# 3   {'purpose': 'leakage-detection', 'experiment_t...
# 4   {'purpose': 'leakage-detection', 'experiment_t...
# 5   {'purpose': 'leakage-detection', 'experiment_t...
# 6   {'purpose': 'test', 'experiment_type': 'inspec...
# 7   {'purpose': 'test', 'experiment_type': 'inspec...
# 8   {'purpose': 'test', 'experiment_type': 'inspec...
# 9   {'purpose': 'test', 'experiment_type': 'inspec...
# 10  {'purpose': 'test', 'experiment_type': 'inspec...
# 11  {'purpose': 'test', 'experiment_type': 'inspec...

# %% [markdown]
# Recall that a model group is defined by the classifier (model_type), its parameters (model_parameters), the features (feature_list), and the model_config. Since we varied the "purpose" key within model_config for these randomized experiments, all other properties of a model group should be used as index keys. This includes other model group keys in the model_config column.

# %%
# pull out all model group keys from model_config column and make new columns from them
list_of_lists = list(model_groups.model_config.apply(lambda x: list(x.keys())))
keys = set([key for x in list_of_lists for key in x])

for key in keys:
    model_groups[key] = model_groups.model_config.apply(lambda x: x.get(key, None))

# %%
# convert model_parameters and feature_list columns to strings so they can be used as index keys
model_groups['model_parameters'] = model_groups.model_parameters.apply(lambda x: ', '.join('{}{}'.format(key, val) for key, val in x.items()))
model_groups['feature_list'] = model_groups.feature_list.apply(lambda x: ', '.join(x))

# %%
index_cols = [col for col in model_groups.columns if col not in ['purpose', 'model_group_id', 'model_config']]
index_cols
# Out:
# ['model_type',
#  'model_parameters',
#  'feature_list',
#  'label_definition',
#  'experiment_type']

# %%
model_groups = model_groups.set_index(index_cols)

# %% [markdown]
# Join the original and randomized model groups to create a wide (rather than long) version of model_group table. Each row of model_groups_wide corresponds to a particular model group configuration and indicates the model group ids of the original vs randomized versions.

# %%
# define original "purpose" model group key
ORIG_PURPOSE = 'test'

# %%
orig = model_groups[model_groups.purpose == ORIG_PURPOSE]
rand = model_groups[model_groups.purpose == 'leakage-detection']
model_groups_wide = pd.merge(orig[['model_group_id']], rand[['model_group_id']], how='right', left_index=True, right_index=True, suffixes = ['_orig', '_rand'])

# %%
model_groups_wide
# Out:
#                                                                                                                                                                     model_group_id_orig  \
# model_type                          model_parameters                feature_list                                       label_definition experiment_type
# sklearn.tree.DecisionTreeClassifier max_depth1, max_features1       inspections_entity_id_3month_type_canvass_sum, ... failed           inspections prioritization                    7
#                                     max_depth1, max_featuressqrt    inspections_entity_id_3month_type_canvass_sum, ... failed           inspections prioritization                    8
#                                     max_depth1, max_featuresNone    inspections_entity_id_3month_type_canvass_sum, ... failed           inspections prioritization                    9
#                                     max_depthNone, max_features1    inspections_entity_id_3month_type_canvass_sum, ... failed           inspections prioritization                   10
#                                     max_depthNone, max_featuressqrt inspections_entity_id_3month_type_canvass_sum, ... failed           inspections prioritization                   11
#                                     max_depthNone, max_featuresNone inspections_entity_id_3month_type_canvass_sum, ... failed           inspections prioritization                   12
#
#                                                                                                                                                                     model_group_id_rand
# model_type                          model_parameters                feature_list                                       label_definition experiment_type
# sklearn.tree.DecisionTreeClassifier max_depth1, max_features1       inspections_entity_id_3month_type_canvass_sum, ... failed           inspections prioritization                    1
#                                     max_depth1, max_featuressqrt    inspections_entity_id_3month_type_canvass_sum, ... failed           inspections prioritization                    2
#                                     max_depth1, max_featuresNone    inspections_entity_id_3month_type_canvass_sum, ... failed           inspections prioritization                    3
#                                     max_depthNone, max_features1    inspections_entity_id_3month_type_canvass_sum, ... failed           inspections prioritization                    4
#                                     max_depthNone, max_featuressqrt inspections_entity_id_3month_type_canvass_sum, ... failed           inspections prioritization                    5
#                                     max_depthNone, max_featuresNone inspections_entity_id_3month_type_canvass_sum, ... failed           inspections prioritization                    6

# %% [markdown]
# Pick a model group configuration on which to test for leakage. Let's go with the first row, where model_group_id_orig = 1, model_group_id_rand = 7

# %%
# create variables for the model_group id's you selected
GROUP_ID_ORIG = 1
GROUP_ID_RAND = 7

# %% [markdown]
# Look at the models relevant to each model group

# %%
statement = "SELECT * FROM results.models where model_group_id = {};".format(GROUP_ID_ORIG)
models_orig = execute_sql(statement, dbname, user, host, password, port)
models_orig
# Out:
#    model_id  model_group_id                        model_hash  \
# 0         1               1  440ed05c425d947f13656439e6d862ed
# 1         7               1  376c959f493b2285a858080553f22edc
#
#                     run_time             batch_run_time  \
# 0 2018-03-29 19:38:16.996957 2018-03-29 19:38:16.992293
# 1 2018-03-29 19:43:03.651427 2018-03-29 19:43:03.648483
#
#                             model_type                     model_parameters  \
# 0  sklearn.tree.DecisionTreeClassifier  {'max_depth': 1, 'max_features': 1}
# 1  sklearn.tree.DecisionTreeClassifier  {'max_depth': 1, 'max_features': 1}
#
#       model_comment batch_comment config                   experiment_hash  \
# 0  inspections_test          None   None  e2cebd41a9610c55b704b115741695a0
# 1  inspections_test          None   None  e2cebd41a9610c55b704b115741695a0
#
#   train_end_time   test                 train_matrix_uuid  \
# 0     2015-12-13  False  e35a116afe12b47979e33ee74060a208
# 1     2016-12-13  False  4da99c0c6b757bc3ff9fa1e6781c2468
#
#   training_label_timespan
# 0                 30 days
# 1                 30 days

# %%
statement = "SELECT * FROM results.models where model_group_id = {};".format(GROUP_ID_RAND)
models_rand = execute_sql(statement, dbname, user, host, password, port)
models_rand
# Out:
#    model_id  model_group_id                        model_hash  \
# 0        13               7  a1a3b6502fb1e63ad80d09a8784b9c0d
# 1        19               7  280fc4f7ade3987a996a6692f72b572b
#
#                     run_time             batch_run_time  \
# 0 2018-03-29 19:52:55.732472 2018-03-29 19:52:55.727932
# 1 2018-03-29 19:53:46.629111 2018-03-29 19:53:46.625838
#
#                             model_type                     model_parameters  \
# 0  sklearn.tree.DecisionTreeClassifier  {'max_depth': 1, 'max_features': 1}
# 1  sklearn.tree.DecisionTreeClassifier  {'max_depth': 1, 'max_features': 1}
#
#       model_comment batch_comment config                   experiment_hash  \
# 0  inspections_test          None   None  7bc94b4256e8a40715be5551934d31ff
# 1  inspections_test          None   None  7bc94b4256e8a40715be5551934d31ff
#
#   train_end_time   test                 train_matrix_uuid  \
# 0     2015-12-13  False  c939d74a584837f89f8213cb2624809a
# 1     2016-12-13  False  b1acc63526a1347ded8daacf449ec51f
#
#   training_label_timespan
# 0                 30 days
# 1                 30 days

# %% [markdown]
# Pick a pair of comparable models on which to test for leakage, i.e. with matching train_end_time. Let's go with the first row of each table, i.e. model_id numbers 1 (original) and 13 (random).
# Grab the predictions made by each of these models.

# %%
# create variables for the model id's you selected
MODEL_ID_ORIG = 1
MODEL_ID_RAND = 13

# %%
statement = "SELECT * FROM results.predictions where model_id = {};".format(MODEL_ID_ORIG)
predictions_orig = execute_sql(statement, dbname, user, host, password, port)
predictions_orig
# Out:
#         model_id  entity_id as_of_date               score label_value  \
# 0              1          2 2015-12-13  0.1977818853974122        None
# 1              1          3 2015-12-13  0.1977818853974122        None
# 2              1          6 2015-12-13  0.1977818853974122        None
# 3              1          9 2015-12-13  0.1977818853974122        None
# 4              1         11 2015-12-13  0.1977818853974122        None
# 5              1         14 2015-12-13  0.1977818853974122        None
# 6              1         16 2015-12-13  0.1977818853974122        None
# 7              1         17 2015-12-13  0.1977818853974122        None
# 8              1         19 2015-12-13  0.1977818853974122        None
# 9              1         21 2015-12-13  0.1977818853974122        None
# 10             1         22 2015-12-13  0.1977818853974122        None
# 11             1         24 2015-12-13  0.1977818853974122        None
# 12             1         25 2015-12-13  0.1977818853974122        None
# 13             1         26 2015-12-13  0.1977818853974122        None
# 14             1         27 2015-12-13  0.1977818853974122        None
# 15             1         28 2015-12-13  0.1977818853974122        None
# 16             1         29 2015-12-13  0.1977818853974122        None
# 17             1         30 2015-12-13  0.1977818853974122        None
# 18             1         31 2015-12-13  0.1977818853974122        None
# 19             1         32 2015-12-13  0.1977818853974122        None
# 20             1         34 2015-12-13  0.1977818853974122        None
# 21             1         35 2015-12-13  0.1977818853974122        None
# 22             1         36 2015-12-13  0.1977818853974122        None
# 23             1         38 2015-12-13  0.1977818853974122        None
# 24             1         39 2015-12-13  0.1977818853974122        None
# 25             1         40 2015-12-13  0.1977818853974122        None
# 26             1         41 2015-12-13  0.1977818853974122        None
# 27             1         43 2015-12-13  0.1977818853974122        None
# 28             1         44 2015-12-13  0.1977818853974122        None
# 29             1         45 2015-12-13  0.1977818853974122        None
# ...          ...        ...        ...                 ...         ...
# 107216         1     165820 2015-12-13  0.1977818853974122        None
# 107217         1     165822 2015-12-13  0.1977818853974122        None
# 107218         1     165823 2015-12-13  0.1977818853974122        None
# 107219         1     165825 2015-12-13  0.1977818853974122        None
# 107220         1     165826 2015-12-13  0.1977818853974122        None
# 107221         1     165827 2015-12-13  0.1977818853974122        None
# 107222         1     165829 2015-12-13  0.1977818853974122        None
# 107223         1     165831 2015-12-13  0.1977818853974122        None
# 107224         1     165832 2015-12-13  0.1977818853974122        None
# 107225         1     165834 2015-12-13  0.1977818853974122        None
# 107226         1     165835 2015-12-13  0.1977818853974122        None
# 107227         1     165837 2015-12-13  0.1977818853974122        None
# 107228         1     165838 2015-12-13  0.1977818853974122        None
# 107229         1     165840 2015-12-13  0.1977818853974122        None
# 107230         1     165841 2015-12-13  0.1977818853974122        None
# 107231         1     165843 2015-12-13  0.1977818853974122        None
# 107232         1     165844 2015-12-13  0.1977818853974122        None
# 107233         1     165845 2015-12-13  0.1977818853974122        None
# 107234         1     165847 2015-12-13  0.1977818853974122        None
# 107235         1     165849 2015-12-13  0.1977818853974122        None
# 107236         1     165850 2015-12-13  0.1977818853974122        None
# 107237         1     165851 2015-12-13  0.1977818853974122        None
# 107238         1     165852 2015-12-13  0.1977818853974122        None
# 107239         1     165853 2015-12-13  0.1977818853974122        None
# 107240         1     165854 2015-12-13  0.1977818853974122        None
# 107241         1     165855 2015-12-13  0.1977818853974122        None
# 107242         1     165860 2015-12-13  0.1977818853974122        None
# 107243         1     165861 2015-12-13  0.1977818853974122        None
# 107244         1     165866 2015-12-13  0.1977818853974122        None
# 107245         1     165867 2015-12-13  0.1977818853974122        None
#
#        rank_abs rank_pct                       matrix_uuid test_label_timespan
# 0          None     None  febde1976e96e5234ec15058565d73c4             30 days
# 1          None     None  febde1976e96e5234ec15058565d73c4             30 days
# 2          None     None  febde1976e96e5234ec15058565d73c4             30 days
# 3          None     None  febde1976e96e5234ec15058565d73c4             30 days
# 4          None     None  febde1976e96e5234ec15058565d73c4             30 days
# 5          None     None  febde1976e96e5234ec15058565d73c4             30 days
# 6          None     None  febde1976e96e5234ec15058565d73c4             30 days
# 7          None     None  febde1976e96e5234ec15058565d73c4             30 days
# 8          None     None  febde1976e96e5234ec15058565d73c4             30 days
# 9          None     None  febde1976e96e5234ec15058565d73c4             30 days
# 10         None     None  febde1976e96e5234ec15058565d73c4             30 days
# 11         None     None  febde1976e96e5234ec15058565d73c4             30 days
# 12         None     None  febde1976e96e5234ec15058565d73c4             30 days
# 13         None     None  febde1976e96e5234ec15058565d73c4             30 days
# 14         None     None  febde1976e96e5234ec15058565d73c4             30 days
# 15         None     None  febde1976e96e5234ec15058565d73c4             30 days
# 16         None     None  febde1976e96e5234ec15058565d73c4             30 days
# 17         None     None  febde1976e96e5234ec15058565d73c4             30 days
# 18         None     None  febde1976e96e5234ec15058565d73c4             30 days
# 19         None     None  febde1976e96e5234ec15058565d73c4             30 days
# 20         None     None  febde1976e96e5234ec15058565d73c4             30 days
# 21         None     None  febde1976e96e5234ec15058565d73c4             30 days
# 22         None     None  febde1976e96e5234ec15058565d73c4             30 days
# 23         None     None  febde1976e96e5234ec15058565d73c4             30 days
# 24         None     None  febde1976e96e5234ec15058565d73c4             30 days
# 25         None     None  febde1976e96e5234ec15058565d73c4             30 days
# 26         None     None  febde1976e96e5234ec15058565d73c4             30 days
# 27         None     None  febde1976e96e5234ec15058565d73c4             30 days
# 28         None     None  febde1976e96e5234ec15058565d73c4             30 days
# 29         None     None  febde1976e96e5234ec15058565d73c4             30 days
# ...         ...      ...                               ...                 ...
# 107216     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107217     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107218     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107219     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107220     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107221     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107222     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107223     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107224     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107225     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107226     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107227     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107228     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107229     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107230     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107231     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107232     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107233     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107234     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107235     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107236     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107237     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107238     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107239     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107240     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107241     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107242     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107243     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107244     None     None  febde1976e96e5234ec15058565d73c4             30 days
# 107245     None     None  febde1976e96e5234ec15058565d73c4             30 days
#
# [107246 rows x 9 columns]

# %%
predictions_orig_sorted = predictions_orig.sort_values(by=['score', 'label_value'], ascending=[False, True])

# %%
statement = "SELECT * FROM results.predictions where model_id = {};".format(MODEL_ID_RAND)
predictions_rand = execute_sql(statement, dbname, user, host, password, port)
predictions_rand
# Out:
#        model_id  entity_id as_of_date                score  label_value  \
# 0            13          1 2015-12-13  0.23247637881784222          NaN
# 1            13          2 2015-12-13  0.23247637881784222          NaN
# 2            13          5 2015-12-13  0.23247637881784222          NaN
# 3            13          6 2015-12-13  0.23247637881784222          NaN
# 4            13          7 2015-12-13  0.23247637881784222          NaN
# 5            13          8 2015-12-13  0.23247637881784222          NaN
# 6            13          9 2015-12-13  0.23247637881784222          NaN
# 7            13         10 2015-12-13  0.23247637881784222          NaN
# 8            13         13 2015-12-13  0.23247637881784222          NaN
# 9            13         14 2015-12-13  0.23247637881784222          NaN
# 10           13         15 2015-12-13  0.23247637881784222          NaN
# 11           13         16 2015-12-13  0.23247637881784222          NaN
# 12           13         17 2015-12-13  0.12384792626728111          NaN
# 13           13         19 2015-12-13  0.23247637881784222          NaN
# 14           13         20 2015-12-13  0.23247637881784222          NaN
# 15           13         21 2015-12-13  0.23247637881784222          NaN
# 16           13         23 2015-12-13  0.23247637881784222          NaN
# 17           13         25 2015-12-13  0.23247637881784222          NaN
# 18           13         27 2015-12-13  0.23247637881784222          NaN
# 19           13         28 2015-12-13  0.23247637881784222          NaN
# 20           13         29 2015-12-13  0.23247637881784222          NaN
# 21           13         30 2015-12-13  0.23247637881784222          NaN
# 22           13         31 2015-12-13  0.23247637881784222          NaN
# 23           13         32 2015-12-13  0.23247637881784222          NaN
# 24           13         35 2015-12-13  0.23247637881784222          NaN
# 25           13         36 2015-12-13  0.23247637881784222          NaN
# 26           13         38 2015-12-13  0.23247637881784222          NaN
# 27           13         39 2015-12-13  0.23247637881784222          NaN
# 28           13         40 2015-12-13  0.23247637881784222          NaN
# 29           13         41 2015-12-13  0.23247637881784222          NaN
# ...         ...        ...        ...                  ...          ...
# 18639        13      34985 2015-12-13  0.12384792626728111          NaN
# 18640        13      34986 2015-12-13  0.23247637881784222          NaN
# 18641        13      34987 2015-12-13  0.12384792626728111          NaN
# 18642        13      34988 2015-12-13  0.12384792626728111          NaN
# 18643        13      34989 2015-12-13  0.12384792626728111          NaN
# 18644        13      34990 2015-12-13  0.12384792626728111          NaN
# 18645        13      34991 2015-12-13  0.12384792626728111          NaN
# 18646        13      34992 2015-12-13  0.12384792626728111          NaN
# 18647        13      34993 2015-12-13  0.12384792626728111          NaN
# 18648        13      34994 2015-12-13  0.12384792626728111          NaN
# 18649        13      34995 2015-12-13  0.12384792626728111          NaN
# 18650        13      34996 2015-12-13  0.12384792626728111          NaN
# 18651        13      34997 2015-12-13  0.23247637881784222          NaN
# 18652        13      34998 2015-12-13  0.23247637881784222          NaN
# 18653        13      34999 2015-12-13  0.23247637881784222          NaN
# 18654        13      35000 2015-12-13  0.23247637881784222          NaN
# 18655        13      35001 2015-12-13  0.23247637881784222          NaN
# 18656        13      35002 2015-12-13  0.23247637881784222          NaN
# 18657        13      35003 2015-12-13  0.23247637881784222          NaN
# 18658        13      35004 2015-12-13  0.23247637881784222          NaN
# 18659        13      35005 2015-12-13  0.23247637881784222          NaN
# 18660        13      35006 2015-12-13  0.23247637881784222          NaN
# 18661        13      35007 2015-12-13  0.12384792626728111          NaN
# 18662        13      35008 2015-12-13  0.12384792626728111          NaN
# 18663        13      35009 2015-12-13  0.23247637881784222          NaN
# 18664        13      35010 2015-12-13  0.12384792626728111          NaN
# 18665        13      35013 2015-12-13  0.12384792626728111          NaN
# 18666        13      35046 2015-12-13  0.23247637881784222          NaN
# 18667        13      35047 2015-12-13  0.23247637881784222          NaN
# 18668        13      35048 2015-12-13  0.23247637881784222          NaN
#
#       rank_abs rank_pct                       matrix_uuid test_label_timespan
# 0         None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 1         None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 2         None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 3         None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 4         None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 5         None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 6         None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 7         None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 8         None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 9         None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 10        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 11        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 12        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 13        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 14        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 15        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 16        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 17        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 19        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 20        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 21        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 22        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 23        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 24        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 25        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 26        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 27        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 28        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 29        None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# ...        ...      ...                               ...                 ...
# 18639     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18640     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18641     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18642     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18643     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18644     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18645     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18646     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18647     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18648     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18649     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18650     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18651     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18652     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18653     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18654     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18655     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18656     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18657     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18658     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18659     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18660     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18661     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18662     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18663     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18664     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18665     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18666     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18667     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
# 18668     None     None  cc5efa865f14af126cee374e3b7dc9f2             30 days
#
# [18669 rows x 9 columns]

# %%
predictions_rand_sorted = predictions_rand.sort_values(by=['score', 'label_value'], ascending=[False, True])

# %% [markdown]
# Grab the evaluation metrics for each of these models.

# %%
statement = "SELECT * FROM results.evaluations where model_id = {};".format(MODEL_ID_ORIG)
evaluations_orig = execute_sql(statement, dbname, user, host, password, port)
evaluations_orig
# Out:
#    model_id evaluation_start_time evaluation_end_time as_of_date_frequency  \
# 0         1            2015-12-13          2015-12-13              30 days
# 1         1            2015-12-13          2015-12-13              30 days
# 2         1            2015-12-13          2015-12-13              30 days
# 3         1            2015-12-13          2015-12-13              30 days
# 4         1            2015-12-13          2015-12-13              30 days
# 5         1            2015-12-13          2015-12-13              30 days
# 6         1            2015-12-13          2015-12-13              30 days
# 7         1            2015-12-13          2015-12-13              30 days
# 8         1            2015-12-13          2015-12-13              30 days
# 9         1            2015-12-13          2015-12-13              30 days
#
#        metric parameter value  num_labeled_examples  \
# 0  precision@   5.0_pct   0.0                     0
# 1     recall@   5.0_pct   0.0                     0
# 2  precision@  10.0_pct   0.0                     0
# 3     recall@  10.0_pct   0.0                     0
# 4  precision@     5_abs   0.0                     0
# 5     recall@     5_abs   0.0                     0
# 6  precision@    10_abs   0.0                     0
# 7     recall@    10_abs   0.0                     0
# 8  precision@    25_abs   0.0                     0
# 9     recall@    25_abs   0.0                     0
#
#    num_labeled_above_threshold  num_positive_labels  sort_seed
# 0                            0                    0          5
# 1                            0                    0          5
# 2                            0                    0          5
# 3                            0                    0          5
# 4                            0                    0          5
# 5                            0                    0          5
# 6                            0                    0          5
# 7                            0                    0          5
# 8                            0                    0          5
# 9                            0                    0          5

# %%
statement = "SELECT * FROM results.evaluations where model_id = {};".format(MODEL_ID_RAND)
evaluations_rand = execute_sql(statement, dbname, user, host, password, port)
evaluations_rand
# Out:
#    model_id evaluation_start_time evaluation_end_time as_of_date_frequency  \
# 0        13            2015-12-13          2015-12-13              30 days
# 1        13            2015-12-13          2015-12-13              30 days
# 2        13            2015-12-13          2015-12-13              30 days
# 3        13            2015-12-13          2015-12-13              30 days
# 4        13            2015-12-13          2015-12-13              30 days
# 5        13            2015-12-13          2015-12-13              30 days
# 6        13            2015-12-13          2015-12-13              30 days
# 7        13            2015-12-13          2015-12-13              30 days
# 8        13            2015-12-13          2015-12-13              30 days
# 9        13            2015-12-13          2015-12-13              30 days
#
#        metric parameter                value  num_labeled_examples  \
# 0  precision@   5.0_pct   0.2553191489361702                   792
# 1     recall@   5.0_pct  0.06629834254143646                   792
# 2  precision@  10.0_pct  0.24468085106382978                   792
# 3     recall@  10.0_pct   0.1270718232044199                   792
# 4  precision@     5_abs                  0.0                   792
# 5     recall@     5_abs                  0.0                   792
# 6  precision@    10_abs                  0.0                   792
# 7     recall@    10_abs                  0.0                   792
# 8  precision@    25_abs                  0.0                   792
# 9     recall@    25_abs                  0.0                   792
#
#    num_labeled_above_threshold  num_positive_labels  sort_seed
# 0                           47                  181          5
# 1                           47                  181          5
# 2                           94                  181          5
# 3                           94                  181          5
# 4                            0                  181          5
# 5                            0                  181          5
# 6                            0                  181          5
# 7                            0                  181          5
# 8                            0                  181          5
# 9                            0                  181          5

# %% [markdown]
# ## V. Perform statistical tests on the randomized model to see if it performs better than random (and thus suggests data leakage)

# %% [markdown]
# Tutorial next steps:
# - Bootstrap (?) the predicted scores to get a large sample of certain evaluation metrics.
# - Perform statistical tests for leakage on those evaluation metrics
#
# NOTE:
# - For simplicity, may skip bootstrapping and perform chi squared test on single result.
# - Need to add complexity and variation to current Dirty Duck model; current one produces same scores for almost everyone.

# %% [markdown]
# Create bootstraped samples of the predicted scores

# %%
# bootstrap_n (int): number of bootstrap samples to run
boostrap_n = 100
bootstrap_samples = []
for n in range(bootstrap_n):
    sample = predictions_rand.scores.sample(predictions_rand.shape[0], replace=True)
    bootstrap_samples.append(sample)

# %%
bootstrap_samples

# %% [markdown]
# Generate labels at a specific threshold, e.g. 10% for each bootstrapped sample set

# %% [markdown]
# Calculate confusion matrix for each bootstrapped sample set

# %% [markdown]
# Perform chi-squared test

# %%
stats.chisquare(f_obs, f_exp, ddof=1)
